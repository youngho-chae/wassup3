# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
import math, time
import bs4
options = Options()
options.add_argument('--window-size=974,1047')
options.add_argument('--window-position=-7,0')
options.add_experimental_option("detach", True)

# %%
URL = 'https://datalab.naver.com/shoppingInsight/sCategory.naver'

driver = webdriver.Chrome(options=options)
driver.get(URL)
time.sleep(3)

# %%
# 제목 추출
title = driver.find_element(By.CLASS_NAME, 'rank_top1000_list').text
print(title)
# Out:
# 1
# 원피스
# 2
# 써스데이아일랜드원피스
# 3
# 여름원피스
# 4
# 블라우스
# 5
# 스투시반팔
# 6
# 여름가디건
# 7
# 자라원피스
# 8
# 남자반바지
# 9
# 시슬리원피스
# 10
# 티셔츠
# 11
# 반바지
# 12
# 남자반팔티
# 13
# 써스데이아일랜드
# 14
# 라코스테원피스
# 15
# 잇미샤원피스
# 16
# 듀엘원피스
# 17
# 롱원피스
# 18
# 지고트원피스
# 19
# 점프수트
# 20
# 써스데이아일랜드블라우스

# %%
driver.find_element(By.CLASS_NAME, 'btn_page_next').click()
time.sleep(2)

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
import math, time
import bs4
options = Options()
options.add_argument('--window-size=974,1047')
options.add_argument('--window-position=-7,0')
options.add_experimental_option("detach", True)

URL = 'https://datalab.naver.com/shoppingInsight/sCategory.naver'

driver = webdriver.Chrome(options=options)
driver.get(URL)
time.sleep(3)

for _ in range(25):
    # 제목 추출
    title = driver.findall_element(By.CLASS_NAME, 'link_text').text
    print(title)
    
    # 다음 버튼 클릭
    driver.find_element(By.CLASS_NAME, 'btn_page_next').click()
    
    # 2초 대기
    time.sleep(2)

print('========= 작업 완료 =========')
driver.close()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[21], line 19
#      15 time.sleep(3)
#      17 for _ in range(25):
#      18     # 제목 추출
# ---> 19     title = driver.findall_element(By.CLASS_NAME, 'link_text').text
#      20     print(title)
#      22     # 다음 버튼 클릭
#
# AttributeError: 'WebDriver' object has no attribute 'findall_element'

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
import time, random, pandas as pd
import math, time, bs4, os

options = Options()
options.add_argument('--window-size=974,1047')
options.add_argument('--window-position=-7,0')
options.add_experimental_option("detach", True)

now = time.localtime()
date_format = '%04d%02d%02d'%(now.tm_year, now.tm_mon, now.tm_mday)
f_dir = f'{os.getcwd()}C:\\Users\\cyh\\Desktop\\{date_format}_TOP 500'
os.makedirs(f_dir, exist_ok=True) # 디렉토리가 미리 존재해도 에러나지 않도록

URL = 'https://datalab.naver.com/shoppingInsight/sCategory.naver'

driver = webdriver.Chrome(options=options)
driver.get(URL)
time.sleep(3)

for _ in range(24):
    # 제목 추출
    title = driver.find_element(By.CLASS_NAME, 'rank_top1000_list').text
    title_lines = title.split('\n')  # 추출된 텍스트를 개별 라인으로 분리
    
    # 짝수 번째 텍스트만 추출
    even_titles = [title_lines[i] for i in range(1, len(title_lines), 2)]
    
    # 짝수 번째 텍스트 출력
    for even_title in even_titles:
        print(even_title)
    
    # 다음 버튼 클릭
    driver.find_element(By.CLASS_NAME, 'btn_page_next').click()
    
    # 2초 대기
    time.sleep(2)

print('========= 작업 완료 =========')
driver.close()
# Out:
# 원피스
# 써스데이아일랜드원피스
# 여름원피스
# 블라우스
# 스투시반팔
# 여름가디건
# 자라원피스
# 남자반바지
# 시슬리원피스
# 티셔츠
# 반바지
# 남자반팔티
# 써스데이아일랜드
# 라코스테원피스
# 잇미샤원피스
# 듀엘원피스
# 롱원피스
# 지고트원피스
# 점프수트
# 써스데이아일랜드블라우스
# 지컷원피스
# 쉬폰원피스
# 린넨셔츠
# 여성원피스
# 데님원피스
# 바스락원피스
# 나이키반바지
# 반팔티
# 라코스테반팔
# 쉬즈미스원피스
# 온앤온원피스
# 플라스틱아일랜드원피스
# 버뮤다팬츠
# 리스트원피스
# 메종키츠네반팔
# 심리스브라
# 자라
# 베네통원피스
# 뷔스티에원피스
# 샤틴원피스
# 냉장고바지
# 잠옷
# 여름블라우스
# 쥬시쥬디원피스
# 에고이스트원피스
# 린넨원피스
# 모조에스핀원피스
# 케네스레이디원피스
# 올리비아로렌
# 듀엘
# 여름잠옷
# 스투시
# 제시뉴욕
# 스커트
# 감탄브라
# 아디다스반바지
# 보브원피스
# 우비
# 여성반바지
# jj지고트원피스
# 스포츠브라
# 블라우스/셔츠
# 여성팬티
# 쉬즈미스
# 반팔자켓
# 반팔블라우스
# 청바지
# 바지
# 여름니트
# bcbg원피스
# 여름자켓
# 톰보이원피스
# 라코스테카라티
# 럭키슈에뜨
# 민소매원피스
# 여성티셔츠
# 치마바지
# 여름청바지
# 크로커다일레이디
# 나시원피스
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[36], line 34
#      31     driver.find_element(By.CLASS_NAME, 'btn_page_next').click()
#      33     # 2초 대기
# ---> 34     time.sleep(2)
# ...

# %%
pwd
# Out:
# 'C:\\workspace\\wassup3\\02_Python_collection'

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
import time, random, pandas as pd
import math, os

options = Options()
options.add_argument('--window-size=974,1047')
options.add_argument('--window-position=-7,0')
options.add_experimental_option("detach", True)

now = time.localtime()
date_format = '%02d%02d_%02d%02d' % (now.tm_mon, now.tm_mday, now.tm_hour, now.tm_min)
f_dir = f'{os.getcwd()}C:\\Users\\cyh\\Desktop\\{date_format}_TOP 500'
os.makedirs(f_dir, exist_ok=True) # 디렉토리가 미리 존재해도 에러나지 않도록

URL = 'https://datalab.naver.com/shoppingInsight/sCategory.naver'

driver = webdriver.Chrome(options=options)
driver.get(URL)
time.sleep(20)

# 데이터를 저장할 리스트
all_even_titles = []

for _ in range(25):
    # 제목 추출
    title = driver.find_element(By.CLASS_NAME, 'rank_top1000_list').text
    title_lines = title.split('\n')  # 추출된 텍스트를 개별 라인으로 분리
    
    # 짝수 번째 텍스트만 추출
    even_titles = [title_lines[i] for i in range(1, len(title_lines), 2)]
    all_even_titles.extend(even_titles)  # 리스트에 추가
    
    # 다음 버튼 클릭
    driver.find_element(By.CLASS_NAME, 'btn_page_next').click()
    
    # 2초 대기
    time.sleep(1)

print('========= 작업 완료 =========')
driver.close()

# 데이터프레임 생성
df = pd.DataFrame(all_even_titles, columns=['Title'])

# 엑셀 파일로 저장
excel_path = os.path.join(f_dir, f'{date_format}_TOP500.xlsx')
df.to_excel(excel_path, index=False)

print(f'엑셀 파일이 {excel_path}에 저장되었습니다.')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[49], line 15
#      13 date_format = '%02d%02d_%02d%02d' % (now.tm_mon, now.tm_mday, now.tm_hour, now.tm_min)
#      14 f_dir = f'{os.getcwd()}C:\\Users\\cyh\\Desktop\\{date_format}_TOP 500'
# ---> 15 os.makedirs(f_dir, exist_ok=True) # 디렉토리가 미리 존재해도 에러나지 않도록
#      17 URL = 'https://datalab.naver.com/shoppingInsight/sCategory.naver'
#      19 driver = webdriver.Chrome(options=options)
#
# File <frozen os>:215, in makedirs(name, mode, exist_ok)
#
# File <frozen os>:215, in makedirs(name, mode, exist_ok)
#
#     [... skipping similar frames: makedirs at line 215 (1 times)]
#
# File <frozen os>:215, in makedirs(name, mode, exist_ok)
#
# File <frozen os>:225, in makedirs(name, mode, exist_ok)
#
# OSError: [WinError 123] 파일 이름, 디렉터리 이름 또는 볼륨 레이블 구문이 잘못되었습니다: 'C:\\workspace\\wassup3\\02_Python_collectionC:'

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
import time, pandas as pd
import os

def start_crawling():
    options = Options()
    options.add_argument('--window-size=974,1047')
    options.add_argument('--window-position=-7,0')
    options.add_experimental_option("detach", True)

    now = time.localtime()
    date_format = '%02d%02d_%02d%02d' % (now.tm_mon, now.tm_mday, now.tm_hour, now.tm_min)
    f_dir = 'C:\\Users\\cyh\\Desktop'  # 저장할 디렉토리 경로

    URL = 'https://datalab.naver.com/shoppingInsight/sCategory.naver'

    driver = webdriver.Chrome(options=options)
    driver.get(URL)
    time.sleep(20)

    # 데이터를 저장할 리스트
    all_even_titles = []

    for _ in range(25):
        # 제목 추출
        title = driver.find_element(By.CLASS_NAME, 'rank_top1000_list').text
        title_lines = title.split('\n')  # 추출된 텍스트를 개별 라인으로 분리
        
        # 짝수 번째 텍스트만 추출
        even_titles = [title_lines[i] for i in range(1, len(title_lines), 2)]
        all_even_titles.extend(even_titles)  # 리스트에 추가
        
        # 다음 버튼 클릭
        driver.find_element(By.CLASS_NAME, 'btn_page_next').click()
        
        # 2초 대기
        time.sleep(1)

    print('========= 작업 완료 =========')
    driver.close()

    # 데이터프레임 생성
    df = pd.DataFrame(all_even_titles, columns=['Title'])

    # 엑셀 파일로 저장
    excel_path = os.path.join(f_dir, f'{date_format}_TOP500.xlsx')
    df.to_excel(excel_path, index=False)

    print(f'엑셀 파일이 {excel_path}에 저장되었습니다.')

while True:
    start_option = input("1. 시작 2. 종료: ")
    if start_option == '1':
        start_crawling()
    elif start_option == '2':
        print("프로그램을 종료합니다.")
        break
    else:
        print("잘못된 입력입니다. 다시 입력해주세요.")
# Out:
# 1. 시작 2. 종료:  1
# ========= 작업 완료 =========
# 엑셀 파일이 C:\Users\cyh\Desktop\0627_1901_TOP500.xlsx에 저장되었습니다.
# 1. 시작 2. 종료:  2
# 프로그램을 종료합니다.

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
import time, pandas as pd
import os

def start_crawling():
    options = Options()
    options.add_argument('--window-size=974,1047')
    options.add_argument('--window-position=-7,0')
    options.add_experimental_option("detach", True)

    now = time.localtime()
    date_format = '%02d%02d_%02d%02d' % (now.tm_mon, now.tm_mday, now.tm_hour, now.tm_min)
    f_dir = 'C:\\Users\\cyh\\Desktop'  # 저장할 디렉토리 경로

    URL = 'https://datalab.naver.com/shoppingInsight/sCategory.naver'

    driver = webdriver.Chrome(options=options)
    driver.get(URL)
    time.sleep(20)

    # 데이터를 저장할 리스트
    all_even_titles = []

    for _ in range(25):
        # 제목 추출
        title = driver.find_element(By.CLASS_NAME, 'rank_top1000_list').text
        title_lines = title.split('\n')  # 추출된 텍스트를 개별 라인으로 분리
        
        # 짝수 번째 텍스트만 추출
        even_titles = [title_lines[i] for i in range(1, len(title_lines), 2)]
        all_even_titles.extend(even_titles)  # 리스트에 추가
        
        # 다음 버튼 클릭
        driver.find_element(By.CLASS_NAME, 'btn_page_next').click()
        
        # 2초 대기
        time.sleep(1)

    print('========= 작업 완료 =========')
    driver.close()

    # 데이터프레임 생성
    df = pd.DataFrame(all_even_titles, columns=['Title'])

    # 엑셀 파일로 저장
    excel_path = os.path.join(f_dir, f'{date_format}_TOP500.xlsx')
    df.to_excel(excel_path, index=False)

    print(f'엑셀 파일이 {excel_path}에 저장되었습니다.')

while True:
    start_option = input("1. 시작 2. 종료: ")
    if start_option == '1':
        start_crawling()
    elif start_option == '2':
        print("프로그램을 종료합니다.")
        break
    else:
        print("잘못된 입력입니다. 다시 입력해주세요.")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[48], line 15
#      13 date_format = '%02d%02d_%02d%02d' % (now.tm_mon, now.tm_mday, now.tm_hour, now.tm_min)
#      14 f_dir = f'{os.getcwd()}C:\\Users\\cyh\\Desktop\\{date_format}_TOP 500'
# ---> 15 os.makedirs(f_dir, exist_ok=True) # 디렉토리가 미리 존재해도 에러나지 않도록
#      17 URL = 'https://datalab.naver.com/shoppingInsight/sCategory.naver'
#      19 driver = webdriver.Chrome(options=options)
#
# File <frozen os>:215, in makedirs(name, mode, exist_ok)
#
# File <frozen os>:215, in makedirs(name, mode, exist_ok)
#
#     [... skipping similar frames: makedirs at line 215 (1 times)]
#
# File <frozen os>:215, in makedirs(name, mode, exist_ok)
#
# File <frozen os>:225, in makedirs(name, mode, exist_ok)
#
# OSError: [WinError 123] 파일 이름, 디렉터리 이름 또는 볼륨 레이블 구문이 잘못되었습니다: 'C:\\workspace\\wassup3\\02_Python_collectionC:'

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
import time, random, pandas as pd
import math, os

options = Options()
options.add_argument('--window-size=974,1047')
options.add_argument('--window-position=-7,0')
options.add_experimental_option("detach", True)

now = time.localtime()
date_format = '%02d%02d%02d%02d' % (now.tm_mon, now.tm_mday, now.tm_hour, now.tm_min)
f_dir = 'C:\\Users\\cyh\\Desktop'  # 저장할 디렉토리 경로
os.makedirs(f_dir, exist_ok=True) # 디렉토리가 미리 존재해도 에러나지 않도록

URL = 'https://datalab.naver.com/shoppingInsight/sCategory.naver'

driver = webdriver.Chrome(options=options)
driver.get(URL)
time.sleep(20)

# 데이터를 저장할 리스트
all_even_titles = []

for _ in range(25):
    # 제목 추출
    title = driver.find_element(By.CLASS_NAME, 'rank_top1000_list').text
    title_lines = title.split('\n')  # 추출된 텍스트를 개별 라인으로 분리
    
    # 짝수 번째 텍스트만 추출
    even_titles = [title_lines[i] for i in range(1, len(title_lines), 2)]
    all_even_titles.extend(even_titles)  # 리스트에 추가
    
    # 다음 버튼 클릭
    driver.find_element(By.CLASS_NAME, 'btn_page_next').click()
    
    # 2초 대기
    time.sleep(1)

print('========= 작업 완료 =========')
driver.close()

# 데이터프레임 생성
df = pd.DataFrame(all_even_titles, columns=['Title'])

# 엑셀 파일로 저장
excel_path = os.path.join(f_dir, f'{date_format}_TOP500.xlsx')
df.to_excel(excel_path, index=False)

print(f'엑셀 파일이 {excel_path}에 저장되었습니다.')
# Out:
# ========= 작업 완료 =========
# 엑셀 파일이 C:\Users\cyh\Desktop\06271918_TOP500.xlsx에 저장되었습니다.

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
import time, pandas as pd
import os

def start_crawling():
    options = Options()
    options.add_argument('--window-size=974,1047')
    options.add_argument('--window-position=-7,0')
    options.add_experimental_option("detach", True)

    now = time.localtime()
    date_format = '%02d%02d%02d%02d' % (now.tm_mon, now.tm_mday, now.tm_hour, now.tm_min)
    f_dir = os.getcwd()  # 현재 작업 디렉토리
    os.makedirs(f_dir, exist_ok=True)  # 디렉토리가 미리 존재해도 에러나지 않도록

    URL = 'https://datalab.naver.com/shoppingInsight/sCategory.naver'

    driver = webdriver.Chrome(options=options)
    driver.get(URL)
    time.sleep(20)

    # 데이터를 저장할 리스트
    all_even_titles = []

    for _ in range(25):
        # 제목 추출
        title = driver.find_element(By.CLASS_NAME, 'rank_top1000_list').text
        title_lines = title.split('\n')  # 추출된 텍스트를 개별 라인으로 분리
        
        # 짝수 번째 텍스트만 추출
        even_titles = [title_lines[i] for i in range(1, len(title_lines), 2)]
        all_even_titles.extend(even_titles)  # 리스트에 추가
        
        # 다음 버튼 클릭
        driver.find_element(By.CLASS_NAME, 'btn_page_next').click()
        
        # 2초 대기
        time.sleep(1)

    print('========= 작업 완료 =========')
    driver.close()

    # 데이터프레임 생성
    df = pd.DataFrame(all_even_titles, columns=['Title'])

    # 엑셀 파일로 저장
    excel_path = os.path.join(f_dir, f'{date_format}_TOP500.xlsx')
    df.to_excel(excel_path, index=False)

    print(f'엑셀 파일이 {excel_path}에 저장되었습니다.')

while True:
    start_option = input("1. 시작 2. 종료: ")
    if start_option == '1':
        start_crawling()
    elif start_option == '2':
        print("프로그램을 종료합니다.")
        break
    else:
        print("잘못된 입력입니다. 다시 입력해주세요.")
# Out:
# 1. 시작 2. 종료:  1
# ========= 작업 완료 =========
# 엑셀 파일이 C:\workspace\wassup3\02_Python_collection\06280834_TOP500.xlsx에 저장되었습니다.
# 1. 시작 2. 종료:  2
# 프로그램을 종료합니다.

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
import time, pandas as pd
import os

def start_crawling():
    options = Options()
    options.add_argument('--window-size=974,1047')
    options.add_argument('--window-position=-7,0')
    options.add_experimental_option("detach", True)

    now = time.localtime()
    date_format = '%02d%02d%02d%02d' % (now.tm_mon, now.tm_mday, now.tm_hour, now.tm_min)
    f_dir = os.getcwd()  # 현재 작업 디렉토리
    os.makedirs(f_dir, exist_ok=True)  # 디렉토리가 미리 존재해도 에러나지 않도록

    URL = 'https://datalab.naver.com/shoppingInsight/sCategory.naver'

    driver = webdriver.Chrome(options=options)
    driver.get(URL)
    time.sleep(10)

    # 데이터를 저장할 리스트
    all_even_titles = []

    for _ in range(25):
        # 제목 추출
        title = driver.find_element(By.CLASS_NAME, 'rank_top1000_list').text
        title_lines = title.split('\n')  # 추출된 텍스트를 개별 라인으로 분리
        
        # 짝수 번째 텍스트만 추출
        even_titles = [title_lines[i] for i in range(1, len(title_lines), 2)]
        all_even_titles.extend(even_titles)  # 리스트에 추가
        
        # 다음 버튼 클릭
        driver.find_element(By.CLASS_NAME, 'btn_page_next').click()
        
        # 2초 대기
        time.sleep(1)

    print('========= 작업 완료 =========')
    driver.close()

    # 데이터프레임 생성
    try:
        df = pd.DataFrame(all_even_titles, columns=['Title'])
    except Exception as e:
        print(f"데이터프레임 생성 중 오류 발생: {e}")
        return

    # 엑셀 파일로 저장
    excel_path = os.path.join(f_dir, f'{date_format}_TOP500.xlsx')
    try:
        df.to_excel(excel_path, index=False, engine='openpyxl')
        print(f'엑셀 파일이 {excel_path}에 저장되었습니다.')
    except Exception as e:
        print(f"엑셀 파일 저장 중 오류 발생: {e}")

while True:
    start_option = input("1. 시작 2. 종료: ")
    if start_option == '1':
        start_crawling()
    elif start_option == '2':
        print("프로그램을 종료합니다.")
        break
    else:
        print("잘못된 입력입니다. 다시 입력해주세요.")
# Out:
# 1. 시작 2. 종료:  1
# ========= 작업 완료 =========
# 엑셀 파일이 C:\workspace\wassup3\02_Python_collection\06280853_TOP500.xlsx에 저장되었습니다.
# 1. 시작 2. 종료:  2
# 프로그램을 종료합니다.

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
import time, pandas as pd
import os

def start_crawling():
    options = Options()
    options.add_argument('--window-size=974,1047')
    options.add_argument('--window-position=-7,0')
    options.add_experimental_option("detach", True)

    now = time.localtime()
    date_format = '%02d%02d%02d%02d' % (now.tm_mon, now.tm_mday, now.tm_hour, now.tm_min)
    f_dir = os.getcwd()  # 현재 작업 디렉토리
    os.makedirs(f_dir, exist_ok=True)  # 디렉토리가 미리 존재해도 에러나지 않도록

    URL = 'https://datalab.naver.com/shoppingInsight/sCategory.naver'

    driver = webdriver.Chrome(options=options)
    driver.get(URL)
    time.sleep(20)

    # 데이터를 저장할 리스트
    all_even_titles = []

    for _ in range(25):
        # 제목 추출
        title = driver.find_element(By.CLASS_NAME, 'rank_top1000_list').text
        title_lines = title.split('\n')  # 추출된 텍스트를 개별 라인으로 분리
        
        # 짝수 번째 텍스트만 추출
        even_titles = [title_lines[i] for i in range(1, len(title_lines), 2)]
        all_even_titles.extend(even_titles)  # 리스트에 추가
        
        # 다음 버튼 클릭
        driver.find_element(By.CLASS_NAME, 'btn_page_next').click()
        
        # 2초 대기
        time.sleep(1)

    print('========= 작업 완료 =========')
    driver.close()

    # 데이터프레임 생성
    try:
        df = pd.DataFrame(all_even_titles, columns=['Title'])
    except Exception as e:
        print(f"데이터프레임 생성 중 오류 발생: {e}")
        return

    # 엑셀 파일로 저장
    excel_path = os.path.join(f_dir, f'{date_format}_TOP500.xlsx')
    try:
        df.to_excel(excel_path, index=False, engine='openpyxl')
        print(f'엑셀 파일이 {excel_path}에 저장되었습니다.')
    except Exception as e:
        print(f"엑셀 파일 저장 중 오류 발생: {e}")

while True:
    start_option = input("1. 시작 2. 종료: ")
    if start_option == '1':
        start_crawling()
    elif start_option == '2':
        print("프로그램을 종료합니다.")
        break
    else:
        print("잘못된 입력입니다. 다시 입력해주세요.")
# Out:
# 1. 시작 2. 종료:  1
# ========= 작업 완료 =========
# 엑셀 파일이 C:\workspace\wassup3\02_Python_collection\06280910_TOP500.xlsx에 저장되었습니다.
# 1. 시작 2. 종료:  2
# 프로그램을 종료합니다.
